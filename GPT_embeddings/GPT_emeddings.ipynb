# %%
import openai
import pandas as pd
import os

# %%
path = '/Users/athena.kam/Documents/Thesis/codebase/thesis-2023-athena'
os.chdir(path)

# %%
api_key = "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"
model = 'text-embedding-ada-002'
embedding_name = 'cl100k_base'
openai.api_key = api_key

# %%
# Inspect data 
def inspect_csv (csv):
    df = pd.read_csv(csv+".csv")
    display(df.head())

inspect_csv("spontaneousDialogueOnly_whisper")
inspect_csv("spontaneousDialogueOnly_wav2vec")
inspect_csv("spontaneousDialogueOnly_google")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 6
#       3     df = pd.read_csv(csv+".csv")
#       4     display(df.head())
# ----> 6 inspect_csv("spontaneousDialogueOnly_whisper")
#       7 inspect_csv("spontaneousDialogueOnly_wav2vec")
#       8 inspect_csv("spontaneousDialogueOnly_google")
#
# Cell In[4], line 3, in inspect_csv(csv)
#       2 def inspect_csv (csv):
# ----> 3     df = pd.read_csv(csv+".csv")
#       4     display(df.head())
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'spontaneousDialogueOnly_whisper.csv'

# %%
import time

def get_embeddings(text: str, model: str) -> list[float]:
    '''
    Calculate embeddings.

    Parameters
    ----------
    text : str
        Text to calculate the embeddings for.
    model : str
        String of the model used to calculate the embeddings.

    Returns
    -------
    list[float]
        List of the embeddings
    '''
    result = openai.Embedding.create(
      model=model,
      input=text
    )
    # delay 
    time.sleep(3)
    
    return result["data"][0]["embedding"]

# %%
def collect_embeddings(filename:str,save_csv:bool):
    df = pd.read_csv(filename+".csv")
    display(df.head())

    print("running through embedder")
    df["embeddings"] = df.transcripts.apply(lambda x:get_embeddings(x,model))

    if save_csv:
        output_name = filename+"_gpt_embeddings.csv"
        df.to_csv(output_name)

    return df

# %%
df_embeddings = collect_embeddings("datasets/spontaneousDialogueOnly_whisper",True)
display(df_embeddings)
# Out:
#                               id
# 0              ID00_hc_0_0_0.wav  \
# 1              ID01_hc_0_0_0.wav
# 2              ID02_pd_2_0_0.wav
# 3  ID03_hc_0_0_0_noPersonalQ.wav
# 4              ID03_hc_0_0_0.wav
#
#                                          transcripts  classification
# 0   Yeah, in London you can go to Oxford Street, ...               0  \
# 1   Okay. Okay. Yes. Okay. So you want to know wh...               0
# 2   So this is your first time in London, you've ...               1
# 3   Okay, so I'm much very long than you're here....               0
# 4   Okay, so I'm much very long than you're here....               0
#
#    noPersonalQ  personalQ
# 0            0          0
# 1            0          0
# 2            0          0
# 3            1          0
# 4            0          1
# running through embedder
#                                        id
# 0                       ID00_hc_0_0_0.wav  \
# 1                       ID01_hc_0_0_0.wav
# 2                       ID02_pd_2_0_0.wav
# 3           ID03_hc_0_0_0_noPersonalQ.wav
# 4                       ID03_hc_0_0_0.wav
# 5           ID04_pd_2_0_1_noPersonalQ.wav
# 6                       ID04_pd_2_0_1.wav
# 7           ID05_hc_0_0_0_noPersonalQ.wav
# 8                       ID05_hc_0_0_0.wav
# 9                       ID06_pd_3_1_1.wav
# 10          ID07_pd_2_0_0_noPersonalQ.wav
# 11                      ID07_pd_2_0_0.wav
# 12                      ID08_hc_0_0_0.wav
# 13                      ID09_hc_0_0_0.wav
# 14          ID10_hc_0_0_0_noPersonalQ.wav
# 15                      ID10_hc_0_0_0.wav
# 16          ID11_hc_0_0_0_noPersonalQ.wav
# 17                      ID11_hc_0_0_0.wav
# 18          ID12_hc_0_0_0_noPersonalQ.wav
# 19                      ID12_hc_0_0_0.wav
# 20                      ID13_pd_3_2_2.wav
# 21                      ID14_hc_0_0_0.wav
# 22          ID15_hc_0_0_0_noPersonalQ.wav
# 23                      ID15_hc_0_0_0.wav
# 24          ID16_pd_2_0_0_noPersonalQ.wav
# 25                      ID16_pd_2_0_0.wav
# 26                      ID17_pd_2_1_0.wav
# 27          ID19_hc_0_0_0_noPersonalQ.wav
# 28                      ID19_hc_0_0_0.wav
# 29          ID20_pd_3_0_1_noPersonalQ.wav
# 30                      ID20_pd_3_0_1.wav
# 31                      ID21_hc_0_0_0.wav
# 32          ID22_hc_0_0_0_noPersonalQ.wav
# 33                      ID22_hc_0_0_0.wav
# 34          ID23_hc_0_0_0_noPersonalQ.wav
# 35                      ID23_hc_0_0_0.wav
# 36          ID24_pd_2_0_0_noPersonalQ.wav
# 37                      ID24_pd_2_0_0.wav
# 38          ID25_hc_0_0_0_noPersonalQ.wav
# 39                      ID25_hc_0_0_0.wav
# 40          ID26_hc_0_0_0_noPersonalQ.wav
# 41                      ID26_hc_0_0_0.wav
# 42          ID27_pd_4_1_1_noPersonalQ.wav
# 43                      ID27_pd_4_1_1.wav
# 44          ID28_hc_0_0_0_noPersonalQ.wav
# 45                      ID28_hc_0_0_0.wav
# 46          ID29_pd_3_1_2_noPersonalQ.wav
# 47                      ID29_pd_3_1_2.wav
# 48          ID30_pd_2_1_1_noPersonalQ.wav
# 49                      ID30_pd_2_1_1.wav
# 50                      ID31_hc_0_1_1.wav
# 51                      ID33_pd_3_2_2.wav
# 52                      ID34_pd_2_0_0.wav
# 53  ID35_hc_0_0_0_noPersonalQuestions.wav
# 54                      ID35_hc_0_0_0.wav
# 55          ID36_hc_0_0_0_noPersonalQ.wav
# 56                      ID36_hc_0_0_0.wav
#
#                                           transcripts  classification
# 0    Yeah, in London you can go to Oxford Street, ...               0  \
# 1    Okay. Okay. Yes. Okay. So you want to know wh...               0
# 2    So this is your first time in London, you've ...               1
# 3    Okay, so I'm much very long than you're here....               0
# 4    Okay, so I'm much very long than you're here....               0
# 5    Yes, yes, I've been asked that question befor...               1
# 6    Yes, yes, I've been asked that question befor...               1
# 7    So I would go and see the Tower of London, wh...               0
# 8    So I would go and see the Tower of London, wh...               0
# 9    Okay, well the first one that comes to mind i...               1
# 10   Okay, well first of all welcome to London and...               1
# 11   Okay, well first of all welcome to London and...               1
# 12   about what? Sorry about what? Oh where I come...               0
# 13   Okay, so in London there are lots of differen...               0
# 14   most impressive. I guess I would say it's I l...               0
# 15   most impressive. I guess I would say it's I l...               0
# 16   What are you interested in? Oh, then Central ...               0
# 17   What are you interested in? Oh, then Central ...               0
# 18   Well, I think all the common touristy places ...               0
# 19   Well, I think all the common touristy places ...               0
# 20   That's the end. Yes, yes. Yes, yes, yes. The ...               1
# 21   Absolutely, there are many, many places. Now ...               0
# 22   So yes, absolutely. You should go and visit s...               0
# 23   So yes, absolutely. You should go and visit s...               0
# 24   Okay, well in London the whole of London is f...               1
# 25   Okay, well in London the whole of London is f...               1
# 26   See that again. Vity the hospital, the hospit...               1
# 27   Well, there are so many nice buildings, get y...               0
# 28   Well, there were so many nice buildings, get ...               0
# 29   I would recommend most of the museums, the Sc...               1
# 30   I would recommend most of the museums, the Sc...               1
# 31   Okay, I think it's good to have a walk along ...               0
# 32   Okay, I'm gonna recommend Central London. Yea...               0
# 33   Okay, thank you. This is great. Now let's try...               0
# 34   Well, the buildings that most people want to ...               0
# 35   Well, the buildings that most people want to ...               0
# 36   You should visit the shard and see London fro...               1
# 37   You should visit the shard and see London fro...               1
# 38   I would suggest you go to the house of the pa...               0
# 39   I would suggest you go to the house of the pa...               0
# 40   Okay, well I definitely think you should visi...               0
# 41   Okay, well I definitely think you should visi...               0
# 42   I believe you all me, I may be here a little ...               1
# 43   I believe you all me, I may be here a little ...               1
# 44   Well, I've always found that Buckingham Palac...               0
# 45   Well, I've always found that Buckingham Palac...               0
# 46   where you've got a horse guard's parade, wedd...               1
# 47   where you've got a horse guard's parade, wedd...               1
# 48   The thing I'd recommend is that you take one ...               1
# 49   The thing I'd recommend is that you take one ...               1
# 50   St. James's Park in London and Buckingham Pal...               0
# 51   What type of food do you like? Indian, Chines...               1
# 52   I recommend seeing the city of London and goi...               1
# 53   some places, can you repeat your questions pl...               0
# 54   some places, can you repeat your questions pl...               0
# 55   Right, if you would like to see some interest...               0
# 56   Right, if you would like to see some interest...               0
#
#     noPersonalQ  personalQ                                         embeddings
# 0             0          0  [0.003226090455427766, 0.00757885305210948, -0...
# 1             0          0  [0.011084314435720444, -0.006076151039451361, ...
# 2             0          0  [0.016482152044773102, -0.0049982089549303055,...
# 3             1          0  [0.002439015544950962, -0.0387580543756485, -0...
# 4             0          1  [0.004061241168528795, -0.037712462246418, -0....
# 5             1          0  [-0.004684170708060265, -0.0046611931174993515...
# 6             0          1  [-0.0005940982373431325, -0.003841835306957364...
# 7             1          0  [-0.01584581844508648, -0.008171317167580128, ...
# 8             0          1  [-0.01826031133532524, -0.02037186734378338, -...
# 9             0          0  [0.004726476967334747, -0.013615313917398453, ...
# 10            1          0  [-0.0043953401036560535, -0.009222686290740967...
# 11            0          1  [-0.001981415320187807, -0.0010643965797498822...
# 12            0          0  [0.026568105444312096, -0.020397702232003212, ...
# 13            0          0  [0.004164508543908596, 0.003157278522849083, -...
# 14            1          0  [0.004332487937062979, 0.0100300507619977, 0.0...
# 15            0          1  [0.0008694934658706188, 0.01589200831949711, -...
# 16            1          0  [0.0012768234591931105, 0.0030337648931890726,...
# 17            0          1  [0.0013197240186855197, -0.007490410003811121,...
# 18            1          0  [0.008604180999100208, -0.0029585196170955896,...
# 19            0          1  [0.0008778468472883105, 0.0018904941389337182,...
# 20            0          0  [-0.004897791426628828, 0.018209215253591537, ...
# 21            0          0  [0.023436516523361206, 0.0009594038710929453, ...
# 22            1          0  [-0.002681425539776683, -0.006511572282761335,...
# 23            0          1  [-0.00044972231262363493, -0.00090990326134487...
# 24            1          0  [0.0036466331221163273, -0.0014478313969448209...
# 25            0          1  [0.004174525383859873, -0.000596360769122839, ...
# 26            0          0  [0.018845222890377045, 0.020805126056075096, 0...
# 27            1          0  [-0.010493413545191288, -0.0014244489138945937...
# 28            0          1  [-0.011406897567212582, -0.006260756868869066,...
# 29            1          0  [-0.006671246141195297, -0.005117353983223438,...
# 30            0          1  [0.00020692900579888374, -0.001614751992747187...
# 31            0          0  [0.014625991694629192, -0.012407587841153145, ...
# 32            1          0  [-0.009135951288044453, -0.01634647697210312, ...
# 33            0          1  [-0.0050219702534377575, -0.002280649263411760...
# 34            1          0  [-0.0032462740782648325, -0.000530641002114862...
# 35            0          1  [0.0029969254974275827, -0.0014328303514048457...
# 36            1          0  [0.007835243828594685, 0.015042622573673725, -...
# 37            0          1  [0.0030016847886145115, 0.011778226122260094, ...
# 38            1          0  [-0.008379238657653332, -0.004937878344208002,...
# 39            0          1  [-0.0036989448126405478, 0.002919717226177454,...
# 40            1          0  [0.016447005793452263, -0.0015335073694586754,...
# 41            0          1  [0.012374352663755417, -0.0044404007494449615,...
# 42            1          0  [0.0054579973220825195, 0.004122530110180378, ...
# 43            0          1  [0.005122320726513863, -0.0005452737677842379,...
# 44            1          0  [-0.004582813475281, -0.007069868966937065, 0....
# 45            0          1  [-0.0063462406396865845, -0.01666267402470112,...
# 46            1          0  [-0.01715032197535038, -0.024473387748003006, ...
# 47            0          1  [-0.012280990369617939, -0.01958509534597397, ...
# 48            1          0  [-0.006180641707032919, -0.023894600570201874,...
# 49            0          1  [0.0027787797152996063, -0.022454120218753815,...
# 50            0          0  [-0.006137080490589142, -0.008895093575119972,...
# 51            0          0  [0.01290145330131054, -0.012723000720143318, -...
# 52            0          0  [-2.9932976758573204e-05, -0.01850820891559124...
# 53            1          0  [-0.020198950543999672, -0.006679411046206951,...
# 54            0          1  [-0.012182367965579033, -0.006160029675811529,...
# 55            1          0  [0.016175206750631332, -0.005546925589442253, ...
# 56            0          1  [0.01362550538033247, 0.0030985509511083364, 0...

# %%
df_embeddings_wav2vec = collect_embeddings("spontaneousDialogueOnly_wav2vec",True)
display(df_embeddings_wav2vec)
# Out:
#                               id
# 0              ID00_hc_0_0_0.wav  \
# 1              ID01_hc_0_0_0.wav
# 2              ID02_pd_2_0_0.wav
# 3  ID03_hc_0_0_0_noPersonalQ.wav
# 4              ID03_hc_0_0_0.wav
#
#                                          transcripts  classification
# 0  Ye m in london ygoi to  oxford streets which i...               0  \
# 1  O k k yes o k am am so you want you want to kn...               0
# 2  So this is your your first time in london you'...               1
# 3  E i so i am not very  londoner here i camp her...               0
# 4  I iso i am not very londoner here i came here ...               0
#
#    noPersonalQ  personalQ
# 0            0          0
# 1            0          0
# 2            0          0
# 3            1          0
# 4            0          1
# running through embedder
#                                        id
# 0                       ID00_hc_0_0_0.wav  \
# 1                       ID01_hc_0_0_0.wav
# 2                       ID02_pd_2_0_0.wav
# 3           ID03_hc_0_0_0_noPersonalQ.wav
# 4                       ID03_hc_0_0_0.wav
# 5           ID04_pd_2_0_1_noPersonalQ.wav
# 6                       ID04_pd_2_0_1.wav
# 7           ID05_hc_0_0_0_noPersonalQ.wav
# 8                       ID05_hc_0_0_0.wav
# 9                       ID06_pd_3_1_1.wav
# 10          ID07_pd_2_0_0_noPersonalQ.wav
# 11                      ID07_pd_2_0_0.wav
# 12                      ID08_hc_0_0_0.wav
# 13                      ID09_hc_0_0_0.wav
# 14          ID10_hc_0_0_0_noPersonalQ.wav
# 15                      ID10_hc_0_0_0.wav
# 16          ID11_hc_0_0_0_noPersonalQ.wav
# 17                      ID11_hc_0_0_0.wav
# 18          ID12_hc_0_0_0_noPersonalQ.wav
# 19                      ID12_hc_0_0_0.wav
# 20                      ID13_pd_3_2_2.wav
# 21                      ID14_hc_0_0_0.wav
# 22          ID15_hc_0_0_0_noPersonalQ.wav
# 23                      ID15_hc_0_0_0.wav
# 24          ID16_pd_2_0_0_noPersonalQ.wav
# 25                      ID16_pd_2_0_0.wav
# 26                      ID17_pd_2_1_0.wav
# 27          ID19_hc_0_0_0_noPersonalQ.wav
# 28                      ID19_hc_0_0_0.wav
# 29          ID20_pd_3_0_1_noPersonalQ.wav
# 30                      ID20_pd_3_0_1.wav
# 31                      ID21_hc_0_0_0.wav
# 32          ID22_hc_0_0_0_noPersonalQ.wav
# 33                      ID22_hc_0_0_0.wav
# 34          ID23_hc_0_0_0_noPersonalQ.wav
# 35                      ID23_hc_0_0_0.wav
# 36          ID24_pd_2_0_0_noPersonalQ.wav
# 37                      ID24_pd_2_0_0.wav
# 38          ID25_hc_0_0_0_noPersonalQ.wav
# 39                      ID25_hc_0_0_0.wav
# 40          ID26_hc_0_0_0_noPersonalQ.wav
# 41                      ID26_hc_0_0_0.wav
# 42          ID27_pd_4_1_1_noPersonalQ.wav
# 43                      ID27_pd_4_1_1.wav
# 44          ID28_hc_0_0_0_noPersonalQ.wav
# 45                      ID28_hc_0_0_0.wav
# 46          ID29_pd_3_1_2_noPersonalQ.wav
# 47                      ID29_pd_3_1_2.wav
# 48          ID30_pd_2_1_1_noPersonalQ.wav
# 49                      ID30_pd_2_1_1.wav
# 50                      ID31_hc_0_1_1.wav
# 51                      ID33_pd_3_2_2.wav
# 52                      ID34_pd_2_0_0.wav
# 53  ID35_hc_0_0_0_noPersonalQuestions.wav
# 54                      ID35_hc_0_0_0.wav
# 55          ID36_hc_0_0_0_noPersonalQ.wav
# 56                      ID36_hc_0_0_0.wav
#
#                                           transcripts  classification
# 0   Ye m in london ygoi to  oxford streets which i...               0  \
# 1   O k k yes o k am am so you want you want to kn...               0
# 2   So this is your your first time in london you'...               1
# 3   E i so i am not very  londoner here i camp her...               0
# 4   I iso i am not very londoner here i came here ...               0
# 5   Yes yes and when ive a  i've been asked that q...               1
# 6   Yes yes and when ive ive i've been asked that ...               1
# 7   Am so i would go and see the tower of london w...               0
# 8   M s i would go and see the tower of london whi...               0
# 9   O q when the first one that comes to mind is a...               1
# 10  Ok well first of all welcome to london and som...               1
# 11  O ke well first of all welcome to london and s...               1
# 12  About what sorry about what oh where come from...               0
# 13  Oh k an so in london there are lots of differe...               0
# 14  Most impressive i guess i would sat si like lo...               0
# 15  Most impressive i guess i would say it si like...               0
# 16  What are you interested then oh then sentra lo...               0
# 17  What are you interested then oh then somtro lo...               0
# 18  Well i think am all the common turistic places...               0
# 19  Well i think em or the common turistic places ...               0
# 20  At in yes e i i  the e mes sacis  interest an ...               1
# 21  Absolutely there are many many places now i ca...               0
# 22  And so yes ad absolutely and you should go and...               0
# 23  A so yes a absolutely ad you should go and vis...               0
# 24  I care well in london the whole of london is f...               1
# 25  I care well in london the whole of london is f...               1
# 26  Se that again visy te hosfy to the otbe to lik...               1
# 27  And well there are so many nice buildings get ...               0
# 28  And well there are so many nice buildings get ...               0
# 29  I reck men most of the museums the youm signs ...               1
# 30  I reck men most of the museums the yum sigens ...               1
# 31  Oh ka i think it's good to have a walk along b...               0
# 32  Ar can am i'm going to recommend i'm saint tra...               0
# 33  Aii o i  o   o ii oa io maii   oai i cay an i'...               0
# 34  Well the most the buildings that most people w...               0
# 35  Wal the most the buildings that most people wa...               0
# 36  You should visit the shard and see london from...               1
# 37  You should visit the shard and see london from...               1
# 38  An tate moden an i would suggest you go to the...               0
# 39  An tate moden an i would suggest you go to the...               0
# 40  O e well i definitely think you should visit t...               0
# 41  I ke well i definitely think you should visit ...               0
# 42  I believe you believe youoll me i may be a lan...               1
# 43  I believe you believe youll me i may be a land...               1
# 44  Wat i've always found at buckinham pallisun do...               0
# 45  What i've always found that backin en palisand...               0
# 46  Where you got hose gars hose gars pride whet i...               1
# 47  Were you got whose cars whose gas pride well e...               1
# 48  Ah the thing i'd recommend is that you take on...               1
# 49  Ah the thing i'd recommend is that you take on...               1
# 50  Am saint james's park in london and buckingham...               0
# 51  O what taper fool dem you like indian tae chin...               1
# 52  A i recommend seein the city of london i'm goi...               1
# 53  Osome places yer can you repeat your questions...               0
# 54  Osome places yer can you repeat your questions...               0
# 55  Why if you like to see some interesting places...               0
# 56  Whig if you like to see some interesting place...               0
#
#     noPersonalQ  personalQ                                         embeddings
# 0             0          0  [0.0029701520688831806, 0.002851085038855672, ...
# 1             0          0  [0.0066466908901929855, -0.001115951337851584,...
# 2             0          0  [0.015947135165333748, -0.0014457388315349817,...
# 3             1          0  [0.007505299989134073, -0.004375808872282505, ...
# 4             0          1  [0.0013732328079640865, -0.01421219389885664, ...
# 5             1          0  [-0.006922222673892975, 0.00010009974357672036...
# 6             0          1  [-0.007101166527718306, 0.003075815737247467, ...
# 7             1          0  [-0.014564195647835732, -0.0011371996952220798...
# 8             0          1  [-0.014179131016135216, 0.0025991627480834723,...
# 9             0          0  [0.0042665814980864525, -0.006786267273128033,...
# 10            1          0  [-0.0031161971855908632, -0.002755356952548027...
# 11            0          1  [0.0004284021269995719, 0.005005518440157175, ...
# 12            0          0  [0.034397415816783905, -0.019197942689061165, ...
# 13            0          0  [-0.000977012561634183, 0.006820125039666891, ...
# 14            1          0  [-0.001154935685917735, 0.010409912094473839, ...
# 15            0          1  [-0.003025677753612399, 0.017436690628528595, ...
# 16            1          0  [0.003251423826441169, 0.0012090131640434265, ...
# 17            0          1  [0.00163585867267102, -0.0032075983472168446, ...
# 18            1          0  [-0.004102385137230158, 0.014356637373566628, ...
# 19            0          1  [-0.006001038942486048, 0.00677338195964694, 0...
# 20            0          0  [0.02111487090587616, 0.02590337209403515, -0....
# 21            0          0  [0.009959332644939423, 0.0006853752420283854, ...
# 22            1          0  [0.0014795954339206219, 0.015212930738925934, ...
# 23            0          1  [-0.002334232209250331, 0.02059498243033886, 0...
# 24            1          0  [-0.004856026265770197, -0.007872086949646473,...
# 25            0          1  [0.0007594656199216843, 0.002159690484404564, ...
# 26            0          0  [0.006556296721100807, 0.012833156622946262, -...
# 27            1          0  [-0.00892859511077404, -0.0002706180384848267,...
# 28            0          1  [-0.01003482099622488, -0.0025432060938328505,...
# 29            1          0  [-0.007230663672089577, 0.00045191647950559855...
# 30            0          1  [-0.004285130184143782, -0.008823361247777939,...
# 31            0          0  [0.009360790252685547, -0.0012162760831415653,...
# 32            1          0  [-0.01559402234852314, -0.00746627151966095, 0...
# 33            0          1  [-0.009522750042378902, 0.010228397324681282, ...
# 34            1          0  [-0.002670884598046541, -0.004849674645811319,...
# 35            0          1  [-0.005108432378619909, 0.004691417794674635, ...
# 36            1          0  [0.006358316168189049, 0.0055977520532906055, ...
# 37            0          1  [-0.0027089808136224747, 0.008860869333148003,...
# 38            1          0  [-0.005815258715301752, 0.00672052800655365, -...
# 39            0          1  [-0.002935060067102313, 0.01879795640707016, 0...
# 40            1          0  [0.012088697403669357, 0.0105593241751194, -0....
# 41            0          1  [0.01157620269805193, 0.007219280116260052, 0....
# 42            1          0  [0.0036599563900381327, 0.0008868224686011672,...
# 43            0          1  [0.0015049675712361932, 0.013459848240017891, ...
# 44            1          0  [-0.006151021923869848, 0.0071785300970077515,...
# 45            0          1  [-0.0015014096861705184, 0.0024929065257310867...
# 46            1          0  [0.003330366685986519, 0.0031289472244679928, ...
# 47            0          1  [0.00017896050121635199, 0.008387573063373566,...
# 48            1          0  [-0.0034998715855181217, -0.00952761247754097,...
# 49            0          1  [0.00124562147539109, -0.010411562398076057, -...
# 50            0          0  [0.008206064812839031, -0.012413610704243183, ...
# 51            0          0  [0.010444581508636475, -0.0023832442238926888,...
# 52            0          0  [-0.002175025176256895, -0.004735915455967188,...
# 53            1          0  [-0.012426516972482204, -0.00608947454020381, ...
# 54            0          1  [0.0015102610923349857, -0.0075692543759942055...
# 55            1          0  [0.005873758811503649, 0.005687451455742121, -...
# 56            0          1  [-0.006813337095081806, 0.005566566716879606, ...

# %%
# df_embeddings_google = collect_embeddings("spontaneousDialogueOnly_google",True)
# display(df_embeddings_google)
